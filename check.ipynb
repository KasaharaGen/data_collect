# %%
import pandas as pd

# %%
df = pd.read_csv("infectious_disease_epmc.csv")

# %%
df.head()
# Out:
#                           DOI  \
# 0  10.1186/s13071-025-06826-8
# 1  10.1186/s13071-025-06829-5
# 2  10.1186/s13071-025-06841-9
# 3  10.1186/s13071-025-06727-w
# 4  10.1186/s13071-025-06663-9
#
#                                                Title  Abstract  FullText  \
# 0  Dynamics of vector competence for dengue virus...       NaN       NaN
# 1  First detection of tick-borne encephalitis vir...       NaN       NaN
# 2  Investigations on the occurrence of West Nile ...       NaN       NaN
# 3  Association between greenspace morphology and ...       NaN       NaN
# 4  Exploiting venom toxins in paratransgenesis to...       NaN       NaN
#
#       Source
# 0  EuropePMC
# 1  EuropePMC
# 2  EuropePMC
# 3  EuropePMC
# 4  EuropePMC

# %%
df.describe()
# Out:
#        Abstract  FullText
# count       0.0       0.0
# mean        NaN       NaN
# std         NaN       NaN
# min         NaN       NaN
# 25%         NaN       NaN
# 50%         NaN       NaN
# 75%         NaN       NaN
# max         NaN       NaN
